# %% [markdown]
# # Compare level 4a and 4b low-level gridded rain rate

# %%
import geopy.distance
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import seaborn as sn
import numpy as np
import xarray as xr
import json
import cartopy
from datetime import datetime
#from adjustText import adjust_text
import pandas as pd
import matplotlib.dates as mdates

# %% [markdown]
# Read in data

# %%
seapol4a = xr.open_dataset('../../data/SEA-POL_gridded_rainrate_spatial_means.nc')
seapol4b = xr.open_dataset('../../data/SEA-POL_4b_rainrate_2D_spatial_means.nc')

# %%
# which domain to plot
seapol4a_domain = seapol4a.rain245_mean
seapol4b_domain = seapol4b.rain245_mean
domain = '245 km'

# %% [markdown]
# Plot

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 2, color='gray',label='4a')
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 2, color='blue',label='4b')

axs.set_xlim(pd.Timestamp('2024-08-16 00:00'), pd.Timestamp('2024-09-23 23:00'))

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/4261216645.py:15: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/4261216645.py:16: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-08-28 00:00'), pd.Timestamp('2024-08-30 00:00'))
#axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3761870709.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3761870709.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-08-30 00:00'), pd.Timestamp('2024-09-01 00:00'))
#axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/1857548037.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/1857548037.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-01 00:00'), pd.Timestamp('2024-09-03 00:00'))
#axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/4022531751.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/4022531751.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-03 00:00'), pd.Timestamp('2024-09-05 00:00'))
#axs.set_ylim(-0.1, 10)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper right')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3173388229.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3173388229.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-05 00:00'), pd.Timestamp('2024-09-07 00:00'))
#axs.set_ylim(0, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/1576041704.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/1576041704.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-07 00:00'), pd.Timestamp('2024-09-09 00:00'))
#axs.set_ylim(-0.1, 6)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper right')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3083783762.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3083783762.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-09 00:00'), pd.Timestamp('2024-09-11 00:00'))
#axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3747816031.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3747816031.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-11 00:00'), pd.Timestamp('2024-09-13 00:00'))
#axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/738260492.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/738260492.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-13 00:00'), pd.Timestamp('2024-09-15 00:00'))
#axs.set_ylim(-0.1, 5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/1557541964.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/1557541964.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-15 00:00'), pd.Timestamp('2024-09-17 00:00'))
#axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper right')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/1083242660.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/1083242660.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-17 00:00'), pd.Timestamp('2024-09-19 00:00'))
#axs.set_ylim(-0.1, 5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/2563799420.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/2563799420.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-19 00:00'), pd.Timestamp('2024-09-21 00:00'))
#axs.set_ylim(-0.1, 10)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3028555725.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3028555725.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-21 00:00'), pd.Timestamp('2024-09-23 00:00'))
#axs.set_ylim(-0.1, 10)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3365135612.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/3365135612.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a_domain, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b_domain, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-22 17:00'), pd.Timestamp('2024-09-23 17:00'))
#axs.set_ylim(-0.1, 5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within ' + domain + ')',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/4155276586.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_77344/4155276586.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.2, '−0.2'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.2, '0.2'),
#  Text(0, 0.4000000000000001, '0.4'),
#  Text(0, 0.6000000000000001, '0.6'),
#  Text(0, 0.8, '0.8'),
#  Text(0, 1.0000000000000002, '1.0'),
#  Text(0, 1.2000000000000002, '1.2'),
#  Text(0, 1.4000000000000001, '1.4'),
#  Text(0, 1.6, '1.6')]
