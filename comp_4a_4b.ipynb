# %% [markdown]
# # Compare level 4a and 4b low-level gridded rain rate

# %%
import geopy.distance
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import seaborn as sn
import numpy as np
import xarray as xr
import json
import cartopy
from datetime import datetime
#from adjustText import adjust_text
import pandas as pd
import matplotlib.dates as mdates

# %% [markdown]
# Read in data

# %%
seapol4a = xr.open_dataset('../../data/SEA-POL_gridded_rainrate_spatial_means.nc')
seapol4b = xr.open_dataset('../../data/SEA-POL_4b_rainrate_2D_spatial_means.nc')

# %% [markdown]
# Plot

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 2, color='gray',label='4a')
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 2, color='blue',label='4b')
axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1384431686.py:13: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1384431686.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -5.0, '−5'),
#  Text(0, 0.0, '0'),
#  Text(0, 5.0, '5'),
#  Text(0, 10.0, '10'),
#  Text(0, 15.0, '15'),
#  Text(0, 20.0, '20'),
#  Text(0, 25.0, '25'),
#  Text(0, 30.0, '30'),
#  Text(0, 35.0, '35')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-01 00:00'), pd.Timestamp('2024-09-03 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/698363382.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/698363382.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-02 00:00'), pd.Timestamp('2024-09-03 00:00'))
axs.set_ylim(-0.1, 10)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/501152094.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/501152094.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -2.0, '−2'),
#  Text(0, 0.0, '0'),
#  Text(0, 2.0, '2'),
#  Text(0, 4.0, '4'),
#  Text(0, 6.0, '6'),
#  Text(0, 8.0, '8'),
#  Text(0, 10.0, '10')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-03 00:00'), pd.Timestamp('2024-09-04 00:00'))
#axs.set_ylim(0, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/434926181.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/434926181.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -5.0, '−5'),
#  Text(0, 0.0, '0'),
#  Text(0, 5.0, '5'),
#  Text(0, 10.0, '10'),
#  Text(0, 15.0, '15'),
#  Text(0, 20.0, '20'),
#  Text(0, 25.0, '25'),
#  Text(0, 30.0, '30'),
#  Text(0, 35.0, '35')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-04 00:00'), pd.Timestamp('2024-09-05 00:00'))
axs.set_ylim(-0.1, 6)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper right')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1413055180.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1413055180.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -1.0, '−1'),
#  Text(0, 0.0, '0'),
#  Text(0, 1.0, '1'),
#  Text(0, 2.0, '2'),
#  Text(0, 3.0, '3'),
#  Text(0, 4.0, '4'),
#  Text(0, 5.0, '5'),
#  Text(0, 6.0, '6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-05 00:00'), pd.Timestamp('2024-09-06 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/3109641446.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/3109641446.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-06 00:00'), pd.Timestamp('2024-09-07 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1725625687.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1725625687.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-07 00:00'), pd.Timestamp('2024-09-08 00:00'))
axs.set_ylim(-0.1, 5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1483735487.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1483735487.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -1.0, '−1'),
#  Text(0, 0.0, '0'),
#  Text(0, 1.0, '1'),
#  Text(0, 2.0, '2'),
#  Text(0, 3.0, '3'),
#  Text(0, 4.0, '4'),
#  Text(0, 5.0, '5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-08 00:00'), pd.Timestamp('2024-09-09 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper right')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/2757074862.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/2757074862.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-09 00:00'), pd.Timestamp('2024-09-10 00:00'))
axs.set_ylim(-0.1, 5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1080435125.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1080435125.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -1.0, '−1'),
#  Text(0, 0.0, '0'),
#  Text(0, 1.0, '1'),
#  Text(0, 2.0, '2'),
#  Text(0, 3.0, '3'),
#  Text(0, 4.0, '4'),
#  Text(0, 5.0, '5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-10 00:00'), pd.Timestamp('2024-09-11 00:00'))
axs.set_ylim(-0.1, 10)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/670024051.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/670024051.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -2.0, '−2'),
#  Text(0, 0.0, '0'),
#  Text(0, 2.0, '2'),
#  Text(0, 4.0, '4'),
#  Text(0, 6.0, '6'),
#  Text(0, 8.0, '8'),
#  Text(0, 10.0, '10')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-11 00:00'), pd.Timestamp('2024-09-12 00:00'))
axs.set_ylim(-0.1, 10)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/976105325.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/976105325.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -2.0, '−2'),
#  Text(0, 0.0, '0'),
#  Text(0, 2.0, '2'),
#  Text(0, 4.0, '4'),
#  Text(0, 6.0, '6'),
#  Text(0, 8.0, '8'),
#  Text(0, 10.0, '10')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-12 00:00'), pd.Timestamp('2024-09-13 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/739521158.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/739521158.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-13 00:00'), pd.Timestamp('2024-09-14 00:00'))
axs.set_ylim(-0.1, 6)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/3664715997.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/3664715997.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -1.0, '−1'),
#  Text(0, 0.0, '0'),
#  Text(0, 1.0, '1'),
#  Text(0, 2.0, '2'),
#  Text(0, 3.0, '3'),
#  Text(0, 4.0, '4'),
#  Text(0, 5.0, '5'),
#  Text(0, 6.0, '6')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-14 00:00'), pd.Timestamp('2024-09-15 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1712526951.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1712526951.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-15 00:00'), pd.Timestamp('2024-09-16 00:00'))
axs.set_ylim(-0.1,10)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/3768814826.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/3768814826.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -2.0, '−2'),
#  Text(0, 0.0, '0'),
#  Text(0, 2.0, '2'),
#  Text(0, 4.0, '4'),
#  Text(0, 6.0, '6'),
#  Text(0, 8.0, '8'),
#  Text(0, 10.0, '10')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-16 00:00'), pd.Timestamp('2024-09-17 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/861395379.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/861395379.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-17 00:00'), pd.Timestamp('2024-09-18 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/3838321084.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/3838321084.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-18 00:00'), pd.Timestamp('2024-09-19 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/2978167598.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/2978167598.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-19 00:00'), pd.Timestamp('2024-09-20 00:00'))
axs.set_ylim(-0.1, 5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1036857774.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1036857774.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -1.0, '−1'),
#  Text(0, 0.0, '0'),
#  Text(0, 1.0, '1'),
#  Text(0, 2.0, '2'),
#  Text(0, 3.0, '3'),
#  Text(0, 4.0, '4'),
#  Text(0, 5.0, '5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-20 00:00'), pd.Timestamp('2024-09-21 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/23259272.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/23259272.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-21 00:00'), pd.Timestamp('2024-09-22 00:00'))
axs.set_ylim(-0.1, 2.5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1405526807.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/1405526807.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -0.5, '−0.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 0.5, '0.5'),
#  Text(0, 1.0, '1.0'),
#  Text(0, 1.5, '1.5'),
#  Text(0, 2.0, '2.0'),
#  Text(0, 2.5, '2.5')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-22 00:00'), pd.Timestamp('2024-09-23 00:00'))
axs.set_ylim(-0.1, 20)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/4286220122.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/4286220122.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -2.5, '−2.5'),
#  Text(0, 0.0, '0.0'),
#  Text(0, 2.5, '2.5'),
#  Text(0, 5.0, '5.0'),
#  Text(0, 7.5, '7.5'),
#  Text(0, 10.0, '10.0'),
#  Text(0, 12.5, '12.5'),
#  Text(0, 15.0, '15.0'),
#  Text(0, 17.5, '17.5'),
#  Text(0, 20.0, '20.0')]

# %%
# Plot time series of precip
fig,axs = plt.subplots(figsize=(12,4),layout="constrained")

############# 1 km
axs.plot(seapol4a.time, seapol4a.rain1_mean, '.', markersize = 8, color='gray',label='4a',alpha=0.5)
axs.plot(seapol4b.time, seapol4b.rain1_mean, '.', markersize = 8, color='blue',label='4b',alpha=0.5)

axs.set_xlim(pd.Timestamp('2024-09-22 17:00'), pd.Timestamp('2024-09-23 17:00'))
#axs.set_ylim(-0.1, 5)

axs.set_ylabel('Rain rate (mm/hr)',fontsize=18)
axs.set_xlabel('Time',fontsize=18)
axs.set_title('Area-Mean Low-Level Rain Rate (within 1 km)',fontsize=18)
axs.xaxis.set_major_locator(mdates.AutoDateLocator())
axs.xaxis.set_major_formatter(mdates.ConciseDateFormatter(axs.xaxis.get_major_locator()))
axs.legend(fontsize=18,loc='upper left')
axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# Out:
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/954688989.py:17: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_xticklabels(axs.get_xticklabels(), fontsize=18)
# /var/folders/ym/zbw7d2hd013cdrqzhhl0z7580000gn/T/ipykernel_70819/954688989.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axs.set_yticklabels(axs.get_yticklabels(), fontsize=18)
# [Text(0, -5.0, '−5'),
#  Text(0, 0.0, '0'),
#  Text(0, 5.0, '5'),
#  Text(0, 10.0, '10'),
#  Text(0, 15.0, '15'),
#  Text(0, 20.0, '20'),
#  Text(0, 25.0, '25'),
#  Text(0, 30.0, '30'),
#  Text(0, 35.0, '35')]
