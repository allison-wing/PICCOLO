# %% [markdown]
# # Plot lapse rate CFAD

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc, colors, ticker
import matplotlib.dates as mdates
from thermo_functions import *
import cmocean
import xarray as xr
import pandas as pd
import seaborn as sns
from orcestra_read_data import *
from thermo_functions import *

# %%
#root_radio = 'https://ipfs.io/ipfs/QmSUUUPcGcpwdJJCVDGPGYksLsqkWbfh6d6xFcTk2Qu7Zf'
#CID: QmbZQh6TcKVaWLj2x5UxqJ2nWcY3He1qwpsVQjCcUip7wq
root_radio = 'ipns://latest.orcestra-campaign.org/products/Radiosondes'
dset_radio = xr.open_dataset(f"{root_radio}/RAPSODI_RS_ORCESTRA_level2.zarr",engine="zarr")
dset_radio = xr.open_dataset(f"https://ipfs.io/ipfs/QmbZQh6TcKVaWLj2x5UxqJ2nWcY3He1qwpsVQjCcUip7wq", engine="zarr")
snd_asc = read_soundings(platform='RV_Meteor', ascent=0) #Read ascending soundings

# Mask soundings that don't reach 100 hPa
snd_asc, min_pres = mask_soundings(snd_asc, p_threshold=100)

times_asc = snd_asc['times']
hght = snd_asc['hght']
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/aiohttp/connector.py:1277, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1273 try:
#    1274     # Cancelling this lookup should not cancel the underlying lookup
#    1275     #  or else the cancel event will get broadcast to all the waiters
#    1276     #  across all connections.
# -> 1277     hosts = await self._resolve_host(host, port, traces=traces)
#    1278 except OSError as exc:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/aiohttp/connector.py:903, in TCPConnector._resolve_host(self, host, port, traces)
#     902 try:
# --> 903     return await asyncio.shield(resolved_host_task)
#     904 except asyncio.CancelledError:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/aiohttp/connector.py:940, in TCPConnector._resolve_host_with_throttle(self, key, host, port, traces)
#     938         await trace.send_dns_resolvehost_start(host)
# --> 940 addrs = await self._resolver.resolve(host, port, family=self._family)
#     941 if traces:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/aiohttp/resolver.py:37, in ThreadedResolver.resolve(self, host, port, family)
#      34 async def resolve(
#      35     self, host: str, port: int = 0, family: socket.AddressFamily = socket.AF_INET
#      36 ) -> List[ResolveResult]:
# ---> 37     infos = await self._loop.getaddrinfo(
#      38         host,
#      39         port,
#      40         type=socket.SOCK_STREAM,
#      41         family=family,
#      42         flags=socket.AI_ADDRCONFIG,
#      43     )
#      45     hosts: List[ResolveResult] = []
#
# File /opt/anaconda3/envs/awing/lib/python3.12/asyncio/base_events.py:901, in BaseEventLoop.getaddrinfo(self, host, port, family, type, proto, flags)
#     899     getaddr_func = socket.getaddrinfo
# --> 901 return await self.run_in_executor(
#     902     None, getaddr_func, host, port, family, type, proto, flags)
#
# File /opt/anaconda3/envs/awing/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/socket.py:964, in getaddrinfo(host, port, family, type, proto, flags)
#     963 addrlist = []
# --> 964 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     965     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# The above exception was the direct cause of the following exception:
#
# ClientConnectorError                      Traceback (most recent call last)
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/zarr/storage.py:1446, in FSStore.__getitem__(self, key)
#    1445 try:
# -> 1446     return self.map[key]
#    1447 except self.exceptions as e:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/fsspec/mapping.py:155, in FSMap.__getitem__(self, key, default)
#     154 try:
# --> 155     result = self.fs.cat(k)
#     156 except self.missing_exceptions:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     117 self = obj or args[0]
# --> 118 return sync(self.loop, func, *args, **kwargs)
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/fsspec/asyn.py:103, in sync(loop, func, timeout, *args, **kwargs)
#     102 elif isinstance(return_result, BaseException):
# --> 103     raise return_result
#     104 else:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/fsspec/asyn.py:56, in _runner(event, coro, result, timeout)
#      55 try:
# ---> 56     result[0] = await coro
#      57 except Exception as ex:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/fsspec/asyn.py:461, in AsyncFileSystem._cat(self, path, recursive, on_error, batch_size, **kwargs)
#     460     if ex:
# --> 461         raise ex
#     462 if (
#     463     len(paths) > 1
#     464     or isinstance(path, list)
#     465     or paths[0] != self._strip_protocol(path)
#     466 ):
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/fsspec/asyn.py:245, in _run_coros_in_chunks.<locals>._run_coro(coro, i)
#     244 try:
# --> 245     return await asyncio.wait_for(coro, timeout=timeout), i
#     246 except Exception as e:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/asyncio/tasks.py:520, in wait_for(fut, timeout)
#     519 async with timeouts.timeout(timeout):
# --> 520     return await fut
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/fsspec/implementations/http.py:234, in HTTPFileSystem._cat_file(self, url, start, end, **kwargs)
#     233 session = await self.set_session()
# --> 234 async with session.get(self.encode_url(url), **kw) as r:
#     235     out = await r.read()
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/aiohttp/client.py:1353, in _BaseRequestContextManager.__aenter__(self)
#    1352 async def __aenter__(self) -> _RetType:
# -> 1353     self._resp = await self._coro
#    1354     return self._resp
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/aiohttp/client.py:657, in ClientSession._request(self, method, str_or_url, params, data, json, cookies, headers, skip_auto_headers, auth, allow_redirects, max_redirects, compress, chunked, expect100, raise_for_status, read_until_eof, proxy, proxy_auth, timeout, verify_ssl, fingerprint, ssl_context, ssl, server_hostname, proxy_headers, trace_request_ctx, read_bufsize, auto_decompress, max_line_size, max_field_size)
#     653     async with ceil_timeout(
#     654         real_timeout.connect,
#     655         ceil_threshold=real_timeout.ceil_threshold,
#     656     ):
# --> 657         conn = await self._connector.connect(
#     658             req, traces=traces, timeout=real_timeout
#     659         )
#     660 except asyncio.TimeoutError as exc:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/aiohttp/connector.py:557, in BaseConnector.connect(self, req, traces, timeout)
#     556 try:
# --> 557     proto = await self._create_connection(req, traces, timeout)
#     558     if self._closed:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/aiohttp/connector.py:967, in TCPConnector._create_connection(self, req, traces, timeout)
#     966 else:
# --> 967     _, proto = await self._create_direct_connection(req, traces, timeout)
#     969 return proto
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/aiohttp/connector.py:1283, in TCPConnector._create_direct_connection(self, req, traces, timeout, client_error)
#    1281     # in case of proxy it is not ClientProxyConnectionError
#    1282     # it is problem of resolving proxy ip itself
# -> 1283     raise ClientConnectorError(req.connection_key, exc) from exc
#    1285 last_exc: Optional[Exception] = None
#
# ClientConnectorError: Cannot connect to host ipfs.io:443 ssl:default [nodename nor servname provided, or not known]
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/xarray/backends/zarr.py:1307, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, stacklevel, zarr_version)
#    1306 try:
# -> 1307     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#    1308 except KeyError:
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/zarr/convenience.py:1360, in open_consolidated(store, metadata_key, mode, **kwargs)
#    1359 # setup metadata store
# -> 1360 meta_store = ConsolidatedStoreClass(store, metadata_key=metadata_key)
#    1362 # pass through
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/zarr/storage.py:3046, in ConsolidatedMetadataStore.__init__(self, store, metadata_key)
#    3045 # retrieve consolidated metadata
# -> 3046 meta = json_loads(self.store[metadata_key])
#    3048 # check format of consolidated metadata
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/zarr/storage.py:1448, in FSStore.__getitem__(self, key)
#    1447 except self.exceptions as e:
# -> 1448     raise KeyError(key) from e
#
# KeyError: '.zmetadata'
#
# During handling of the above exception, another exception occurred:
#
# GroupNotFoundError                        Traceback (most recent call last)
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/xarray/backends/zarr.py:1310, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, stacklevel, zarr_version)
#    1309 try:
# -> 1310     zarr_group = zarr.open_group(store, **open_kwargs)
#    1311     warnings.warn(
#    1312         "Failed to open Zarr store with consolidated metadata, "
#    1313         "but successfully read with non-consolidated metadata. "
#    (...)
#    1324         stacklevel=stacklevel,
#    1325     )
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/zarr/hierarchy.py:1578, in open_group(store, mode, cache_attrs, synchronizer, path, chunk_store, storage_options, zarr_version, meta_array)
#    1577             raise ContainsArrayError(path)
# -> 1578         raise GroupNotFoundError(path)
#    1580 elif mode == "w":
#
# GroupNotFoundError: group not found at path ''
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 5
#       1 #root_radio = 'https://ipfs.io/ipfs/QmSUUUPcGcpwdJJCVDGPGYksLsqkWbfh6d6xFcTk2Qu7Zf'
#       2 #CID: QmbZQh6TcKVaWLj2x5UxqJ2nWcY3He1qwpsVQjCcUip7wq
#       3 #root_radio = 'ipns://latest.orcestra-campaign.org/products/Radiosondes'
#       4 #dset_radio = xr.open_dataset(f"{root_radio}/RAPSODI_RS_ORCESTRA_level2.zarr",engine="zarr")
# ----> 5 dset_radio = xr.open_dataset(f"https://ipfs.io/ipfs/QmbZQh6TcKVaWLj2x5UxqJ2nWcY3He1qwpsVQjCcUip7wq", engine="zarr")
#       6 snd_asc = read_soundings(platform='RV_Meteor', ascent=0) #Read ascending soundings
#       8 # Mask soundings that don't reach 100 hPa
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/xarray/backends/api.py:571, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     559 decoders = _resolve_decoders_kwargs(
#     560     decode_cf,
#     561     open_backend_dataset_parameters=backend.open_dataset_parameters,
#    (...)
#     567     decode_coords=decode_coords,
#     568 )
#     570 overwrite_encoded_chunks = kwargs.pop("overwrite_encoded_chunks", None)
# --> 571 backend_ds = backend.open_dataset(
#     572     filename_or_obj,
#     573     drop_variables=drop_variables,
#     574     **decoders,
#     575     **kwargs,
#     576 )
#     577 ds = _dataset_from_backend_dataset(
#     578     backend_ds,
#     579     filename_or_obj,
#    (...)
#     589     **kwargs,
#     590 )
#     591 return ds
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/xarray/backends/zarr.py:1167, in ZarrBackendEntrypoint.open_dataset(self, filename_or_obj, mask_and_scale, decode_times, concat_characters, decode_coords, drop_variables, use_cftime, decode_timedelta, group, mode, synchronizer, consolidated, chunk_store, storage_options, stacklevel, zarr_version, store, engine)
#    1165 filename_or_obj = _normalize_path(filename_or_obj)
#    1166 if not store:
# -> 1167     store = ZarrStore.open_group(
#    1168         filename_or_obj,
#    1169         group=group,
#    1170         mode=mode,
#    1171         synchronizer=synchronizer,
#    1172         consolidated=consolidated,
#    1173         consolidate_on_close=False,
#    1174         chunk_store=chunk_store,
#    1175         storage_options=storage_options,
#    1176         stacklevel=stacklevel + 1,
#    1177         zarr_version=zarr_version,
#    1178     )
#    1180 store_entrypoint = StoreBackendEntrypoint()
#    1181 with close_on_error(store):
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/xarray/backends/zarr.py:483, in ZarrStore.open_group(cls, store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, append_dim, write_region, safe_chunks, stacklevel, zarr_version, write_empty)
#     464 @classmethod
#     465 def open_group(
#     466     cls,
#    (...)
#     480     write_empty: bool | None = None,
#     481 ):
# --> 483     zarr_group, consolidate_on_close, close_store_on_close = _get_open_params(
#     484         store=store,
#     485         mode=mode,
#     486         synchronizer=synchronizer,
#     487         group=group,
#     488         consolidated=consolidated,
#     489         consolidate_on_close=consolidate_on_close,
#     490         chunk_store=chunk_store,
#     491         storage_options=storage_options,
#     492         stacklevel=stacklevel,
#     493         zarr_version=zarr_version,
#     494     )
#     496     return cls(
#     497         zarr_group,
#     498         mode,
#    (...)
#     504         close_store_on_close,
#     505     )
#
# File /opt/anaconda3/envs/awing/lib/python3.12/site-packages/xarray/backends/zarr.py:1327, in _get_open_params(store, mode, synchronizer, group, consolidated, consolidate_on_close, chunk_store, storage_options, stacklevel, zarr_version)
#    1311             warnings.warn(
#    1312                 "Failed to open Zarr store with consolidated metadata, "
#    1313                 "but successfully read with non-consolidated metadata. "
#    (...)
#    1324                 stacklevel=stacklevel,
#    1325             )
#    1326         except zarr.errors.GroupNotFoundError:
# -> 1327             raise FileNotFoundError(f"No such file or directory: '{store}'")
#    1328 elif consolidated:
#    1329     # TODO: an option to pass the metadata_key keyword
#    1330     zarr_group = zarr.open_consolidated(store, **open_kwargs)
#
# FileNotFoundError: No such file or directory: 'https://ipfs.io/ipfs/QmbZQh6TcKVaWLj2x5UxqJ2nWcY3He1qwpsVQjCcUip7wq'
