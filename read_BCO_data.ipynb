# %%
import geopy.distance
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import seaborn as sn
import numpy as np
import xarray as xr
import json
import cartopy
from datetime import datetime
from adjustText import adjust_text
import pandas as pd
import matplotlib.dates as mdates
import intake

# %%
DSHIP = xr.open_dataset('../../data/meteor_meteo_dship_20240923.nc')

# %%
cat = intake.open_catalog("https://tcodata.mpimet.mpg.de/catalog.yaml")
wxt = cat.BCO.surfacemet_wxt_v1.to_dask()
wxt["T"].sel(time="2020-01").plot(figsize=(12, 4));

# %%
wxt
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:  (time: 34431903)
# Coordinates:
#     alt      float32 4B ...
#     lat      float32 4B ...
#     lon      float32 4B ...
#   * time     (time) datetime64[ns] 275MB 2010-12-16T16:24:00 ... 2023-03-15T2...
# Data variables: (12/27)
#     DIR      (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     DL       (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     DR       (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     H        (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     HDH      (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     HDS      (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     ...       ...
#     TH       (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     TI       (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     VEL      (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     VH       (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     VR       (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
#     VS       (time) float32 138MB dask.array<chunksize=(2592000,), meta=np.ndarray>
# Attributes:
#     Conventions:      CF-1.8
#     bcoproc_version:  2.0.1.dev238+gd8a1f09
#     created_with:     /home/m/m300827/micromamba/envs/bcoproc_test/bin/bcopro...
#     creation_date:    Fri Apr 28 18:52:53 2023
#     devices:          Vaisala WXT-520
#     height:           about 29 m above MSL; about 4m above ground
#     institution:      Max Planck Institute for Meteorology, Hamburg
#     location:         The Barbados Cloud Observatory, Deebles Point, Barbados...
#     position:         13.1627 N, -59.4289 E
#     title:            WXT-2 ground station
#     tool_versions:    {"Python": "3.10.6 | packaged by conda-forge | (main, A...

# %%
cat
# Out:
# tcodata_mpimet_mpg_de:
#   args:
#     path: https://tcodata.mpimet.mpg.de/catalog.yaml
#   description: ''
#   driver: intake.catalog.local.YAMLFileCatalog
#   metadata: {}
