# %%
import xarray as xr

# %%
ds = xr.open_dataset('ipns://latest.orcestra-campaign.org/products/HALO/dropsondes/Level_3/PERCUSION_Level_3.zarr',engine='zarr')
ds
# Out:
# <xarray.Dataset> Size: 156MB
# Dimensions:                (sonde_id: 1115, gpsalt: 1460)
# Coordinates:
#     aircraft_latitude      (sonde_id) float32 4kB ...
#     aircraft_longitude     (sonde_id) float32 4kB ...
#     aircraft_msl_altitude  (sonde_id) float32 4kB ...
#     flight_id              (sonde_id) <U14 62kB ...
#   * gpsalt                 (gpsalt) float64 12kB 0.0 10.0 ... 1.459e+04
#     launch_time            (sonde_id) datetime64[ns] 9kB ...
#     platform_id            (sonde_id) <U4 18kB ...
#   * sonde_id               (sonde_id) <U9 40kB '231221036' ... '232320070'
# Data variables: (12/25)
#     alt                    (sonde_id, gpsalt) float32 7MB ...
#     gps_N_qc               (sonde_id, gpsalt) int64 13MB ...
#     gpspos_N_qc            (sonde_id, gpsalt) int64 13MB ...
#     interp_time            (sonde_id, gpsalt) datetime64[ns] 13MB ...
#     iwv                    (sonde_id) float32 4kB ...
# ...
